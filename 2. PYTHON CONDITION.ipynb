# %% [markdown]
# <a href="https://colab.research.google.com/github/gourdaksh4/Python-/blob/main/2.%20PYTHON%20CONDITION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Create Age =  20 Use if to print 'Adult' if age is greater than or equal to 18

# %%
age = 20

if age >= 18:
   print ("Adult")
# Out:
# Adult

# %% [markdown]
# Create Marks = 80 Use if to print "Pass" If Marks are greater than or equal to 40

# %%
marks = 80

if marks >= 50:
   print ("PASS")
# Out:
# PASS

# %% [markdown]
# Create number = 10 Use if to print "Number is greater than 5" if the number is greater than 5

# %%
number = 10

if number > 5:
   print ("Number is greater than 5")
# Out:
# Number is greater than 5

# %% [markdown]
# Create temperature = 35 use if to print "It is hot" if the temperature is greater than 30

# %%
temperature = 35

if temperature > 30:
    print ("it is hot")
# Out:
# it is hot

# %% [markdown]
# Create Age = 25 use if to print "ELIGIBLE" IF AGE IS GRATER THAN OR EQUAL TO 18

# %%
age = 25

if age >= 18:
  print ("Eligible")
# Out:
# Eligible

# %% [markdown]
# Create marks =90 use if to print "EXCELLENT" if marks are grater than or equal to 80

# %%
marks = 90

if marks >= 90:
     print ("Excellent")
# Out:
# Excellent

# %% [markdown]
# Create number = 100 use if to print "Number is 100" if the number is equal to 100

# %%
number - 100

if number == 100:
     print ("number is 100")

# %% [markdown]
# Create:
# Use if to print "a is greater" is a is greater than b

# %%
a = 20
b = 10

if a > b:
  print ("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# Create salary = 50000 use if to print " Good salary" if salary is greater than 30000

# %%
salary = 50000

if salary > 30000:
   print ("Good salary")
# Out:
# Good salary

# %% [markdown]
# Create number = 15 use if to print "positive" if the number is greater than 0

# %%
number = 15

if number > 0:
   print ("positive")
# Out:
# positive

# %% [markdown]
# Create hour = 10 use if to print 'good morning' if hour is less than 12

# %%
hour = 10

if hour < 12:
   print ('good morning')
# Out:
# good morning

# %%
Create is-admin = true use if to print 'admin access granted' if is-admin is true

# %%
is_admin = True

if is_admin:
   print ("Admin Access Granted")
# Out:
# Admin Access Granted

# %% [markdown]
# Create num_items = 7 use if to print 'bulk discount ! ' if num_items is greater than 5

# %%
num_items = 7

if num_items > 5:
   print ('bulk discount!')
# Out:
# bulk discount!

# %% [markdown]
# Create password = ' secret' use if to print 'login successful' if password is equal to 'secret'

# %%
password = 'secret'

if password == 'secret':
   print ('login successful')
# Out:
# login successful

# %% [markdown]
# Create has_license = false use if to print ' license required' if has_license is false

# %%
has_license = False


if has_license is False:
   print ('license required')
# Out:
# license required

# %% [markdown]
# Create balance = -50 use if to print 'account overdrawn' if balance is less than o

# %%
balance = -50

if balance < 0:
   print ("account overdrawn")
# Out:
# account overdrawn

# %% [markdown]
# Create day = 'sunday' use if to print 'weekend vibes' if day is equal to 'sunday'

# %%
day = 'Sunday'

if day == 'sunday':
   print ('weekend vibes')

# %% [markdown]
# Create grade = 75 use if to print 'passed' if grae is grater than or equal to 70

# %%
grade = 75

if grade >= 70:
   print ('passed')
# Out:
# passed

# %% [markdown]
# Create is_active = False use if to print ' user inactive' if is_active is not true

# %%
is_active = False

if not is_active:
   print ('user inactive')
# Out:
# user inactive

# %% [markdown]
# Create age = 18 use if to print 'just turned 18!' if age is equal to 18

# %%
age = 18

if age ==18:
   print ('just turned 18!')
# Out:
# just turned 18!
